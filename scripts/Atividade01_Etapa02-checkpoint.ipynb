# %% [markdown]
# ## AULA 03 - PYTHON

# %% [markdown]
# Nesta aula veremos:\
#     **1. Numpy arrays e pandas Dataframes**\
#    **2. Open and export files**\
#    **3. Conditional Statements**\
#    **4. Loops em Python**\
#     **5. Functions - def**

# %% [markdown]
# ## 1.1 Numpy arrays

# %%
import numpy as np

# Criando um vetor de dados aleatórios
data=np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.52193348 0.46213677]
#  [0.76575194 0.70887614]
#  [0.54127187 0.60981196]
#  [0.16973509 0.27012551]
#  [0.13245511 0.83600915]
#  [0.66208948 0.31105173]
#  [0.88369514 0.53860078]
#  [0.46347973 0.90940336]
#  [0.92826883 0.48443496]
#  [0.61697915 0.71180726]]
# (10, 2)

# %% [markdown]
# O np.random.rand cria uma lista de elementos aleatórios que variam de 0 a 1.
#
# O shape mostra o tamanho da matriz em linhas e colunas e o size mostra o número de elementos ao todo na matriz.
#
# O 0:10 está mostrando valores das linhas de 0 a 9, para requisitar algo das colunas precisa usar uma vírgula.

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
# Out:
# [[526.7141409  467.51539794]
#  [768.09442531 711.78737879]
#  [545.85914752 613.71383899]
#  [178.0377405  277.42425935]
#  [141.13056294 837.6490613 ]
#  [665.46858388 317.94120988]
#  [884.85818514 543.21477233]
#  [468.8449341  910.30932891]
#  [928.98614511 489.59060869]
#  [620.80936332 714.68918266]]

# %% [markdown]
# Operações matemáticas com o array, primeiro multiplicou todos os valores por 990 depois somou 10.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(data)
ax[1].plot(data[:,0])
ax[2].plot(data[:,1])
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Tive que instalar o matplotlib com 'pip install matplotlib' no prompt de comando, para sair do prompt tem que usar ctrl c.

# %% [markdown]
# Cria 3 subplots e em cada ax é indexado a posição de cada subplot.

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.74759753 0.46353059 0.20300515 ... 0.42254996 0.18155196 0.30649815]
#  [0.65361696 0.75908373 0.20435565 ... 0.00508236 0.04878651 0.34092308]
#  [0.47447578 0.32508287 0.68750542 ... 0.37541383 0.18672869 0.74097541]
#  ...
#  [0.67477357 0.44575423 0.25833706 ... 0.09697399 0.05704126 0.15451314]
#  [0.30216008 0.28098183 0.31693603 ... 0.58756223 0.49273769 0.1093399 ]
#  [0.8407549  0.55406612 0.68348463 ... 0.20705249 0.3924792  0.75464143]]

# %% [markdown]
# Está puxando os valores de seno em radianos do array 1000 por 1000.

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)
plt.show()

# %%
# Criando vetor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h"))
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# Está fazendo um arang começando em 1/1/22 e indo até 1/1/23 com passo de 1h entre cada valor do array.

# %% [markdown]
# Data está em ano-mês-dia, e valores horários se dão em hora:minuto:segundo:ms.

# %% [markdown]
# ## PANDAS

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %% [markdown]
# Criando um dataframe vazio.

# %%
# Monstrando um dataframe
df['datetime'] = dtime

# %% [markdown]
# Criando coluna com o array de valores de tempo.

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %% [markdown]
# Criando colunas de valores aleatórios com tamanho igual ao valor de linhas do df.

# %%
df['random'][1:10]
# Out:
# 1    0.974279
# 2    0.799947
# 3    0.014575
# 4    0.262082
# 5    0.458702
# 6    0.119662
# 7    0.294009
# 8    0.575318
# 9    0.979449
# Name: random, dtype: float64

# %%
# Indexação
df.iloc[:,0]
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %% [markdown]
# .loc localiza uma posição específica do df baseado no index.

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.029953
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.974279
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.799947
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.014575
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.262082
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.805259
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.956160
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.721117
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.009291
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.460925
#
# [8760 rows x 2 columns]

# %% [markdown]
# Passando o valor da coluna de datatime para o index do df.

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %% [markdown]
# Transformando os valores de ano, mês e dia em novas colunas no df.

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %% [markdown]
# Criando uma lista com os valores do número de linhas do df, fazendo transformações numéricas nesta lista e depois plotando a nova coluna que foi adicionada ao df.

# %%
df
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.029953  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.974279  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.799947  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.014575  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.262082  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.805259  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.956160  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.721117  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.009291  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.460925  2022     12   31  0.979958
#
# ...

# %%
# Salvar meu dataframe

df.to_csv(r"C:/Users/supor/OneDrive/Documentos/ControlePoluicaoAtm/ENS5173_202401/Dados/Brutos/noise_2022.csv")

# %% [markdown]
# Salvando o df gerado como csv na pasta indicada.

# %%
# Criando uma função
def noiseCreation(path, year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Leonardo
    """
    
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # Monstrando um dataframe
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv')
    
    return df

# %% [markdown]
# Criando uma função que automatiza os passos anteriores de forma prática. Ao final cria um gráfico da sazonalidade e um arquivo csv do df na pasta indicada.

# %%
path = "C:/Users/supor/OneDrive/Documentos/ControlePoluicaoAtm/ENS5173_202401/Dados/Brutos"
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010):
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %% [markdown]
# Loop mostrando diversos anos em sequência.

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.476315  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.049380  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.571180  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.868745  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.894521  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.307322  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.123950  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.190107  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.103179  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.349796  0.979958
#
# ...

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos:
    print(ano)
    if ano > 2030:
        df = noiseCreation(path,ano)
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %% [markdown]
# For para puxar apenas os valores requisitados, neste caso, valores do ano acima de 2030.

# %%
import os
files = os.listdir(path)
print(files)

allData = []
for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data)
# Out:
# ['noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %% [markdown]
# Listando os arquivos criados na pasta e juntando eles em uma lista só.

# %%
allDataDf = pd.concat(allData)

# %% [markdown]
# Concatenando os valores dos csvs em um só dataframe.

# %%
allDataDf
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.276955
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.776663
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.618013
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.132726
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.165413
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.928685
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.702309
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.602698
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.072204
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.513329
#
#        sazonal  timeSeries
# 0     1.000000   10.276955
# ...

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])

# %% [markdown]
# ## A partir daqui foram testes que eu fiz enquanto aprendia cada parte do conteúdo desta aula.

# %%
eixox=[1,2,3]
eixoy=[7,2,9]
plt.scatter(eixox,eixoy, label='Segmento Azul', ls=':', color='m',lw=5, marker='8')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('Voltagem')
plt.xticks([0,2,4,6,8,10])
plt.yticks([0,2,4,6.47,8,10])
plt.legend()
plt.show()

# %%
#testex=np.array([[1,2,3,4],[9,10,11,12]])
#testey=np.array([[5,6,7,8], [13,14,15,16]])
testez=np.random.rand(1000,1000)
print('teste x: \n',testex)
print('teste y: \n', testey)
print('teste z: \n', testez)
# Out:
# teste x:
#  [[ 1  2  3  4]
#  [ 9 10 11 12]]
# teste y:
#  [[ 5  6  7  8]
#  [13 14 15 16]]
# teste z:
#  [[0.09769045 0.31108199 0.24985251 ... 0.48927662 0.3746453  0.03312411]
#  [0.50637005 0.362188   0.36881715 ... 0.52968654 0.4870472  0.15010439]
#  [0.39492843 0.4341067  0.43833163 ... 0.19051614 0.32611579 0.30354721]
#  ...
#  [0.57674441 0.21208936 0.30522195 ... 0.83572833 0.51293775 0.41609714]
#  [0.94300777 0.86161237 0.80849072 ... 0.74414155 0.00935438 0.24576375]
#  [0.08311334 0.50258353 0.31616992 ... 0.87215929 0.33718435 0.07193262]]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(5, figsize=(5,5), facecolor='lightskyblue', layout='constrained')
fig.suptitle('Figura teste')
ax[0].plot(testez)
ax[1].plot(testez[:,0])
ax[2].plot(testez[:,1])
ax[3].plot(testez[3,:])
print(type(testez))
# Out:
# <class 'numpy.ndarray'>

# %%
np.sin([0.29])
# Out:
# array([0.28595223])

# %%
fig4, ax4=plt.subplots()
ax4.pcolor(testex)

# %%
np.arange('2005-11','2006-02', dtype='datetime64[Y]')
# Out:
# array(['2005'], dtype='datetime64[Y]')

# %%
np.arange('2005-11','2006-02', dtype='datetime64[M]')
# Out:
# array(['2005-11', '2005-12', '2006-01'], dtype='datetime64[M]')

# %%
np.arange('2005-11','2006-02', dtype='datetime64[D]')
# Out:
# array(['2005-11-01', '2005-11-02', '2005-11-03', '2005-11-04',
#        '2005-11-05', '2005-11-06', '2005-11-07', '2005-11-08',
#        '2005-11-09', '2005-11-10', '2005-11-11', '2005-11-12',
#        '2005-11-13', '2005-11-14', '2005-11-15', '2005-11-16',
#        '2005-11-17', '2005-11-18', '2005-11-19', '2005-11-20',
#        '2005-11-21', '2005-11-22', '2005-11-23', '2005-11-24',
#        '2005-11-25', '2005-11-26', '2005-11-27', '2005-11-28',
#        '2005-11-29', '2005-11-30', '2005-12-01', '2005-12-02',
#        '2005-12-03', '2005-12-04', '2005-12-05', '2005-12-06',
#        '2005-12-07', '2005-12-08', '2005-12-09', '2005-12-10',
#        '2005-12-11', '2005-12-12', '2005-12-13', '2005-12-14',
#        '2005-12-15', '2005-12-16', '2005-12-17', '2005-12-18',
#        '2005-12-19', '2005-12-20', '2005-12-21', '2005-12-22',
#        '2005-12-23', '2005-12-24', '2005-12-25', '2005-12-26',
#        '2005-12-27', '2005-12-28', '2005-12-29', '2005-12-30',
# ...

# %% [markdown]
# np.arange(inicio,fim,passo).

# %%
np.datetime64('2009') + np.timedelta64(7, 'D')
# Out:
# numpy.datetime64('2009-01-08')

# %%
np.datetime64('2009-01-01') - np.datetime64('2008-01-01')
# Out:
# numpy.timedelta64(366,'D')

# %%
np.datetime64('2011-06-15T00:00') + np.timedelta64(12, 'h')+np.timedelta64(47,'m')
# Out:
# numpy.datetime64('2011-06-15T12:47')

# %%
np.timedelta64(1,'W') / np.timedelta64(1,'D')
# Out:
# 7.0

# %%
np.timedelta64(1,'W') % np.timedelta64(10,'D')
# Out:
# numpy.timedelta64(7,'D')
